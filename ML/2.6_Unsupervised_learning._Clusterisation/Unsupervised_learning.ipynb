# %%
from sklearn.ensemble import IsolationForest 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import datasets
from sklearn.linear_model import LogisticRegressionCV
from sklearn.feature_selection import VarianceThreshold

from pyod.models.knn import KNN 

import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
from tqdm import tqdm

sns.set()

# %% [markdown]
# ## Кластеризация

# %% [markdown]
# ### K-means

# %% [markdown]
# Сгенерируем произвольные данные

# %%
data = np.array([[np.random.rand(), np.random.rand()] for _ in range(500)])

# %%
sns.scatterplot(
    data=pd.DataFrame(data, columns=['f1', 'f2']), 
    x='f1',
    y='f2',
    palette='deep',
    s=10
)
# Out:
# /tmp/ipykernel_339/997464193.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# <Axes: xlabel='f1', ylabel='f2'>

# %% [markdown]
# Обучим метод K-средних

# %%
# Обучение модели
model = KMeans(4, random_state=12)
model.fit(data)

print("Центроиды кластеров:")
print(model.cluster_centers_)
# Out:
# Центроиды кластеров:
# [[0.70629733 0.74626385]
#  [0.22248013 0.27137358]
#  [0.75754291 0.25397139]
#  [0.23975129 0.79029468]]

# %%
data
# Out:
# array([[4.97660102e-01, 5.54005821e-01],
#        [6.89834349e-01, 5.94371218e-01],
#        [7.65266443e-01, 3.98172815e-01],
#        [7.29907548e-01, 4.25518676e-01],
#        [1.93889869e-01, 2.44565360e-01],
#        [5.00893965e-01, 8.63594612e-01],
#        [8.93096585e-01, 1.97184209e-01],
#        [5.23741299e-01, 7.02052019e-01],
#        [5.15434303e-01, 5.10637686e-01],
#        [5.16097018e-01, 3.74707094e-01],
#        [1.82621080e-01, 9.71618622e-01],
#        [8.50648296e-02, 9.45690549e-01],
#        [5.04625560e-01, 9.16539412e-01],
#        [8.79320598e-01, 1.99604074e-01],
#        [5.72525712e-01, 6.99998523e-04],
#        [9.82862957e-01, 6.51209251e-01],
#        [4.50001607e-01, 7.53899130e-01],
#        [9.39843043e-01, 7.17618790e-01],
#        [5.50743718e-01, 7.37433183e-01],
#        [2.08338229e-01, 9.44837058e-01],
#        [2.21929869e-01, 4.62509451e-02],
#        [6.97663696e-02, 9.40533257e-01],
#        [5.02087801e-01, 5.20093374e-01],
#        [9.17584678e-01, 1.17037700e-01],
#        [8.85520971e-02, 9.04435219e-01],
#        [9.97401999e-01, 8.51406368e-01],
#        [5.54684773e-01, 6.84511293e-01],
#        [8.54193603e-01, 6.39838917e-01],
#        [8.75621724e-01, 7.92071151e-01],
#        [5.73612732e-01, 2.31963501e-01],
#        [2.62770818e-01, 6.81311986e-01],
#        [9.25171663e-01, 3.01284000e-01],
#        [9.83346672e-01, 7.80698677e-01],
#        [5.91326273e-01, 8.00172582e-01],
#        [5.75246549e-01, 4.26720328e-01],
#        [6.45993971e-01, 8.22785202e-01],
#        [3.30556356e-01, 1.79132541e-01],
#        [7.34834578e-02, 4.01723694e-01],
#        [7.97530352e-01, 1.61801107e-01],
#        [7.48223584e-01, 5.85501257e-01],
#        [4.22149128e-01, 9.39997305e-01],
#        [3.16541106e-01, 9.41950672e-01],
#        [8.77081610e-01, 6.71875475e-02],
#        [4.58511362e-01, 3.62550714e-01],
#        [4.61800498e-01, 2.34682706e-01],
#        [2.15153792e-01, 3.67554859e-01],
#        [8.71318384e-01, 6.23164013e-01],
#        [4.82542966e-01, 2.88361072e-01],
#        [6.36174905e-01, 2.14719949e-01],
#        [6.94153722e-01, 7.08696148e-01],
#        [7.93737871e-01, 3.07271752e-01],
#        [8.62772052e-01, 7.68377492e-01],
#        [2.35653882e-02, 6.64795501e-01],
#        [6.57767513e-01, 5.23918342e-01],
#        [2.07397374e-01, 5.24558835e-01],
#        [9.80780403e-02, 9.11519028e-01],
#        [1.20446516e-02, 2.76249579e-01],
#        [1.14608284e-01, 4.62830133e-01],
#        [1.93989095e-01, 2.64682075e-01],
#        [6.37114091e-01, 5.59235580e-01],
#        [9.65815345e-01, 1.29734567e-01],
#        [5.85885324e-01, 9.32592504e-01],
#        [8.47912239e-01, 2.59872981e-03],
#        [6.75012025e-01, 7.66988589e-01],
#        [2.77510986e-01, 3.74297365e-01],
#        [5.16869370e-01, 3.31682459e-01],
#        [9.75003792e-01, 3.86172182e-01],
#        [4.08363741e-01, 6.08947212e-01],
#        [3.05292061e-01, 8.70279896e-01],
#        [2.79262239e-01, 4.82052277e-01],
#        [8.44097856e-03, 3.25245725e-02],
#        [6.28656496e-01, 8.38780342e-01],
#        [3.03101582e-01, 1.52408686e-02],
#        [6.25324272e-01, 5.19483074e-01],
#        [8.11480166e-01, 2.85888857e-01],
#        [8.61065051e-01, 5.75042011e-01],
#        [3.64531014e-01, 3.43942348e-01],
#        [7.04085398e-01, 9.91008946e-01],
#        [4.66544215e-01, 6.99466600e-01],
#        [6.66413894e-01, 9.54114043e-01],
#        [2.44277543e-01, 2.88555564e-01],
#        [9.53527391e-01, 6.14749799e-01],
#        [1.72980417e-01, 9.30394881e-01],
#        [5.63705892e-01, 9.68672248e-01],
#        [1.03787842e-01, 6.91876363e-02],
#        [2.89973715e-01, 3.94561661e-01],
#        [9.72747558e-01, 9.71206755e-01],
#        [5.14245200e-01, 4.82233303e-02],
#        [5.08327676e-01, 4.34943235e-01],
#        [7.42540580e-01, 1.68089420e-01],
#        [9.80212708e-01, 5.78046275e-01],
#        [4.94994417e-01, 9.93907278e-01],
#        [7.94943915e-01, 5.51968854e-01],
#        [6.00301748e-01, 2.71001665e-01],
#        [3.23416015e-02, 9.19290800e-01],
#        [4.19008025e-01, 8.26626451e-01],
#        [6.75087025e-01, 2.36340904e-01],
#        [1.32806086e-01, 6.03170128e-01],
#        [5.36750877e-01, 6.82321069e-01],
#        [3.17816231e-02, 4.19294310e-01],
#        [8.23443101e-01, 3.58644536e-01],
#        [8.40762384e-01, 3.07036280e-01],
#        [5.22211818e-01, 3.94453673e-02],
#        [4.92979216e-03, 4.60071508e-01],
#        [1.82017317e-01, 9.16459377e-01],
#        [4.90895484e-01, 7.98381515e-01],
#        [9.42760479e-01, 4.58127613e-01],
#        [8.81522080e-01, 1.49866544e-01],
#        [1.69832626e-01, 5.11704725e-01],
#        [5.93407458e-02, 8.92401239e-01],
#        [3.07679329e-01, 2.11293445e-01],
#        [9.91970113e-01, 3.53915626e-01],
#        [5.45004339e-01, 9.47755300e-01],
#        [1.92870411e-01, 8.92380951e-01],
#        [6.52115975e-01, 8.80108603e-01],
#        [6.42746378e-01, 6.28226086e-02],
#        [1.55210029e-01, 2.45741223e-01],
#        [5.63839562e-01, 4.10713159e-01],
#        [3.81904718e-01, 8.57224908e-01],
#        [3.23358159e-01, 6.60641594e-01],
#        [7.63572360e-01, 9.43841296e-01],
#        [4.32705020e-01, 3.32665873e-01],
#        [2.89426321e-01, 6.66587864e-01],
#        [3.35508180e-02, 4.30492154e-01],
#        [7.70367660e-02, 7.91017985e-01],
#        [2.86371804e-02, 2.29885879e-01],
#        [2.31867373e-01, 5.97555318e-02],
#        [9.53496153e-01, 3.30923165e-02],
#        [9.29420964e-01, 8.68019778e-01],
#        [4.82761536e-01, 8.38693431e-01],
#        [2.81317148e-03, 2.94351709e-01],
#        [3.40161364e-01, 9.40270278e-02],
#        [4.24975702e-01, 9.68989393e-01],
#        [5.09935644e-01, 2.72664978e-02],
#        [9.90639872e-01, 4.65071928e-01],
#        [8.28212822e-01, 5.37902787e-01],
#        [2.96911928e-01, 5.86602807e-01],
#        [6.30804316e-01, 3.45065824e-01],
#        [6.23556207e-01, 9.64212173e-01],
#        [8.84204258e-02, 3.19922237e-01],
#        [1.50907513e-01, 2.51833024e-02],
#        [5.93332473e-01, 9.08381095e-01],
#        [5.40337528e-01, 9.64328793e-02],
#        [4.61521920e-02, 1.52951772e-01],
#        [3.56025834e-01, 6.04117450e-01],
#        [7.42448365e-01, 6.69464266e-02],
#        [3.79755556e-01, 7.32542498e-01],
#        [8.09086757e-01, 8.13973538e-01],
#        [2.24101081e-02, 1.59811579e-01],
#        [7.47506557e-01, 1.68139665e-02],
#        [4.22592035e-01, 9.80394718e-01],
#        [4.27851100e-02, 4.57651937e-01],
#        [8.59840158e-01, 3.41778114e-01],
#        [4.86288117e-01, 4.38079598e-01],
#        [7.16905865e-01, 1.31922910e-01],
#        [4.31371766e-01, 3.46385980e-01],
#        [2.85719675e-01, 4.32487623e-01],
#        [5.21070407e-01, 8.81181903e-01],
#        [9.55768953e-01, 9.97692000e-01],
#        [4.21472043e-03, 1.81173561e-01],
#        [7.57011591e-01, 6.18424161e-01],
#        [8.23730676e-01, 3.54018679e-01],
#        [8.90949265e-01, 2.32851755e-01],
#        [8.97450778e-01, 8.01524246e-01],
#        [9.67830806e-01, 5.38053358e-01],
#        [2.06910125e-01, 2.76990793e-02],
#        [9.32766606e-01, 8.44420327e-01],
#        [4.23542770e-01, 6.76760098e-01],
#        [4.55123426e-01, 9.90879355e-01],
#        [2.74111893e-01, 2.19600640e-01],
#        [2.05317177e-01, 4.96484250e-01],
#        [5.05820223e-01, 5.78338228e-01],
#        [3.96101899e-01, 7.81499981e-01],
#        [1.33307437e-01, 9.12021049e-01],
#        [6.55249321e-01, 6.06935293e-01],
#        [9.61076703e-01, 4.19111040e-01],
#        [1.32632737e-01, 1.64105759e-02],
#        [6.81132335e-02, 3.88561609e-02],
#        [8.29885352e-01, 4.02827200e-01],
#        [1.94966379e-01, 9.79840822e-01],
#        [1.64645466e-01, 3.51546529e-01],
#        [3.15912119e-02, 3.42435351e-01],
#        [6.31203362e-01, 4.84589263e-02],
#        [9.49041261e-01, 5.74788906e-01],
#        [5.38155427e-01, 2.37755707e-01],
#        [2.97381964e-01, 6.83834203e-01],
#        [9.71600434e-02, 1.16418060e-01],
#        [4.97247798e-01, 7.28134193e-01],
#        [4.95438520e-01, 3.40913803e-01],
#        [4.82130357e-01, 1.92153223e-01],
#        [3.56618260e-02, 8.67066981e-02],
#        [8.65179814e-02, 3.11052005e-01],
#        [9.98159215e-01, 5.01241709e-01],
#        [2.91053169e-01, 7.19570682e-01],
#        [9.95771125e-01, 4.18891766e-01],
#        [4.55510393e-01, 2.18424642e-01],
#        [2.91593112e-01, 8.59440856e-01],
#        [3.91688742e-01, 6.57133659e-01],
#        [3.02840588e-01, 3.34413735e-01],
#        [6.13421848e-01, 9.77306882e-02],
#        [6.01525060e-01, 6.48356389e-01],
#        [6.40903868e-01, 9.41928759e-01],
#        [6.40539931e-01, 2.10069862e-01],
#        [6.76035587e-01, 5.22217022e-01],
#        [7.62835522e-01, 4.60456908e-01],
#        [6.17020346e-01, 8.64596001e-01],
#        [5.80811060e-01, 7.20628307e-01],
#        [2.14790353e-01, 2.77542999e-01],
#        [1.75728951e-01, 8.80876433e-01],
#        [7.21312485e-01, 8.44475830e-01],
#        [2.85473592e-01, 1.30412698e-01],
#        [4.59402204e-01, 6.82285075e-01],
#        [5.78187710e-01, 4.50292516e-01],
#        [6.23387502e-01, 1.30076005e-01],
#        [3.37724981e-01, 8.11820267e-01],
#        [7.08356258e-01, 5.62729452e-01],
#        [8.32986271e-01, 9.96437902e-01],
#        [7.50229217e-01, 6.84123349e-01],
#        [6.66098504e-01, 3.47020895e-02],
#        [2.09782609e-01, 2.36146151e-01],
#        [7.24927782e-01, 2.80359448e-02],
#        [1.51462868e-01, 3.50357778e-02],
#        [1.37503434e-01, 1.28161071e-01],
#        [3.92712805e-01, 5.39457080e-01],
#        [2.41378854e-01, 8.78267464e-01],
#        [6.97885677e-01, 9.91886889e-01],
#        [5.90765663e-01, 3.98613084e-01],
#        [2.20394165e-01, 9.33763862e-01],
#        [1.34017347e-01, 6.93622109e-01],
#        [5.34076537e-01, 5.46534490e-01],
#        [8.19774204e-02, 3.12979042e-01],
#        [5.23906919e-01, 4.09270270e-01],
#        [5.67541309e-01, 7.87152252e-01],
#        [1.21856180e-01, 4.60716223e-01],
#        [1.44509226e-01, 5.72423043e-01],
#        [3.34907050e-01, 4.66100967e-01],
#        [3.39990260e-01, 7.11024008e-01],
#        [3.27224528e-01, 4.59636977e-01],
#        [3.56813218e-01, 1.04019416e-01],
#        [2.25234453e-01, 9.78318926e-02],
#        [8.91912103e-01, 4.06289184e-01],
#        [6.41078964e-01, 3.81834256e-01],
#        [4.12815740e-01, 2.62888728e-01],
#        [8.73840594e-01, 4.60776643e-01],
#        [2.54765856e-01, 9.87331299e-03],
#        [8.74114114e-01, 2.45666017e-02],
#        [4.16939291e-01, 9.22800760e-01],
#        [9.68701662e-01, 4.40160727e-01],
#        [6.51356744e-01, 8.17110610e-01],
#        [8.75632857e-01, 5.64572611e-01],
#        [5.94247937e-01, 9.82623091e-01],
#        [9.90209183e-02, 3.04991426e-01],
#        [5.71326425e-01, 2.11396619e-01],
#        [7.29682630e-02, 1.18683287e-01],
#        [9.31683419e-01, 9.05732714e-01],
#        [1.08461074e-01, 4.92465611e-01],
#        [6.86531850e-01, 4.93069343e-02],
#        [6.38953493e-01, 1.34630071e-01],
#        [4.80502310e-01, 9.83848033e-02],
#        [4.96887106e-01, 8.39501208e-01],
#        [3.06695825e-01, 2.63655752e-01],
#        [5.92899343e-01, 4.72988463e-01],
#        [7.65947311e-01, 7.37376461e-01],
#        [4.57910590e-01, 8.44462823e-01],
#        [1.04309420e-01, 2.21510692e-01],
#        [5.15993908e-01, 8.28068425e-01],
#        [8.70233852e-01, 5.10240391e-01],
#        [8.01666846e-01, 3.81827530e-01],
#        [9.55765984e-01, 9.59317573e-01],
#        [7.95962084e-01, 9.13470138e-01],
#        [3.72682957e-01, 7.25781347e-01],
#        [3.00393437e-03, 3.47945289e-01],
#        [1.22207942e-01, 8.55860758e-01],
#        [8.13076955e-01, 1.67669470e-01],
#        [2.09119448e-01, 2.67116597e-01],
#        [8.72058619e-02, 6.85774581e-01],
#        [9.74665008e-01, 1.62537059e-01],
#        [4.60580704e-01, 1.36856233e-01],
#        [4.76986145e-01, 9.21079629e-01],
#        [6.10983594e-01, 7.58600015e-01],
#        [6.82061436e-01, 6.04281867e-01],
#        [5.75267934e-01, 7.02049626e-01],
#        [2.46676931e-01, 3.00416706e-01],
#        [8.42505992e-01, 7.68218670e-01],
#        [3.56017034e-01, 3.84481188e-01],
#        [8.29954416e-01, 4.89096630e-01],
#        [2.32877898e-01, 3.04691054e-01],
#        [8.02825787e-01, 8.32405895e-01],
#        [9.62773602e-01, 3.12840824e-01],
#        [7.89825786e-01, 3.54320562e-01],
#        [5.32822244e-01, 6.71340826e-01],
#        [2.03936671e-01, 9.27683886e-01],
#        [3.73970002e-01, 5.99956522e-01],
#        [8.71616734e-01, 8.70665650e-01],
#        [1.93445110e-01, 8.62832677e-01],
#        [8.43757782e-01, 2.61091717e-01],
#        [6.92562317e-03, 9.93160115e-01],
#        [7.19632217e-01, 7.39639869e-01],
#        [2.34564011e-02, 3.50791860e-01],
#        [6.00557571e-01, 8.30825350e-01],
#        [9.95427185e-01, 6.28801340e-01],
#        [8.48332200e-01, 1.77824417e-01],
#        [4.37859518e-01, 8.96622742e-02],
#        [4.49115680e-02, 8.73519100e-01],
#        [6.25998517e-01, 6.80223344e-01],
#        [7.76786744e-02, 1.77224184e-01],
#        [2.34820027e-01, 7.18706629e-01],
#        [1.39157659e-01, 6.11292289e-01],
#        [5.47769353e-01, 3.68867992e-02],
#        [9.39518015e-01, 1.13338648e-01],
#        [7.80615002e-01, 9.35915729e-01],
#        [1.33729347e-01, 1.55015688e-01],
#        [9.27777486e-01, 4.52942694e-02],
#        [3.13359799e-01, 8.37061069e-01],
#        [8.13558385e-01, 4.44865092e-01],
#        [6.45016711e-01, 3.05982978e-01],
#        [2.79125627e-01, 1.05875673e-01],
#        [2.33006814e-01, 6.87947379e-01],
#        [3.15364284e-01, 7.51047328e-01],
#        [6.04688331e-01, 6.30630225e-01],
#        [9.43592352e-01, 3.73091001e-01],
#        [2.23398494e-01, 7.11262511e-02],
#        [3.42557408e-01, 4.35729762e-01],
#        [4.62509471e-01, 5.72798532e-01],
#        [6.25466265e-01, 8.85719631e-02],
#        [7.44809048e-03, 9.65829252e-01],
#        [6.01543975e-01, 9.44277379e-01],
#        [8.26972273e-01, 2.73070291e-01],
#        [5.13784095e-01, 9.65368815e-01],
#        [5.90788640e-01, 5.71731171e-01],
#        [1.26315286e-01, 9.13126580e-01],
#        [5.83512614e-01, 7.94764883e-01],
#        [3.51103614e-01, 2.27212707e-01],
#        [3.20228094e-01, 3.70038620e-02],
#        [6.09418153e-02, 2.38386387e-01],
#        [8.23458287e-01, 1.61365028e-01],
#        [2.68947229e-01, 9.31835570e-01],
#        [1.30006540e-01, 7.49028345e-01],
#        [8.43009517e-01, 8.06849982e-02],
#        [2.19107797e-01, 4.07087514e-01],
#        [3.21481591e-01, 5.97206006e-01],
#        [2.84159355e-01, 1.92605899e-01],
#        [9.21324545e-01, 5.57184653e-01],
#        [9.33254458e-01, 9.69687138e-01],
#        [6.98493739e-01, 7.66941494e-01],
#        [9.54862212e-01, 8.25719890e-01],
#        [6.43675438e-01, 6.34707511e-01],
#        [3.28090516e-02, 7.37028997e-01],
#        [7.12774780e-01, 5.71596300e-01],
#        [9.73522955e-01, 5.01158514e-02],
#        [6.27778909e-01, 7.81340435e-01],
#        [8.21509519e-01, 7.11877587e-01],
#        [7.46983698e-01, 8.30446667e-01],
#        [4.26622527e-01, 5.66090294e-01],
#        [3.12624509e-02, 3.55875785e-01],
#        [1.18739287e-01, 4.61493501e-01],
#        [5.21412038e-01, 6.84639035e-01],
#        [4.61200305e-01, 7.15817539e-01],
#        [7.01237980e-01, 8.30193824e-01],
#        [5.86175818e-01, 8.02866423e-01],
#        [6.27690125e-01, 9.92619078e-01],
#        [8.76712132e-01, 1.16922722e-01],
#        [8.64535246e-01, 7.61460901e-01],
#        [2.13900714e-01, 3.47897616e-01],
#        [9.84122691e-02, 2.20352099e-01],
#        [8.12591480e-01, 6.94158445e-01],
#        [3.12160869e-01, 6.49045062e-01],
#        [5.20334875e-02, 5.11494428e-01],
#        [3.12147801e-01, 3.30871147e-01],
#        [5.20299603e-01, 3.69413452e-01],
#        [1.98282909e-01, 8.86846153e-01],
#        [5.11157002e-01, 9.99357234e-01],
#        [2.56007537e-01, 2.85465504e-01],
#        [6.07144417e-01, 5.97215301e-01],
#        [5.29202667e-01, 2.17682916e-01],
#        [7.58913608e-01, 1.42517369e-01],
#        [3.52119156e-01, 5.40655963e-01],
#        [1.04703703e-01, 7.13300191e-01],
#        [7.87205343e-01, 7.38019246e-02],
#        [7.24841877e-01, 3.23164684e-01],
#        [4.02177130e-01, 6.75120765e-01],
#        [2.68779962e-01, 3.85420879e-01],
#        [7.06407847e-01, 5.70981796e-01],
#        [2.69593138e-01, 7.61528063e-01],
#        [5.89186077e-01, 8.04796992e-01],
#        [5.02631173e-01, 5.11652234e-01],
#        [3.71506475e-01, 4.32973767e-01],
#        [5.80417183e-01, 2.92853208e-01],
#        [7.08532310e-02, 6.71639609e-01],
#        [9.09256650e-02, 3.68095631e-01],
#        [3.18280249e-01, 3.06549748e-02],
#        [2.90629446e-02, 6.34045038e-01],
#        [8.85172534e-01, 3.94582360e-01],
#        [1.09564752e-01, 2.53298942e-01],
#        [7.32138832e-01, 5.13242202e-01],
#        [3.92689016e-01, 9.97401187e-02],
#        [3.60447142e-01, 1.08337310e-02],
#        [3.49348376e-01, 8.22840382e-01],
#        [5.41251861e-01, 4.16507000e-01],
#        [5.60365375e-02, 1.59951231e-01],
#        [9.42516456e-01, 3.92258938e-01],
#        [1.66916377e-01, 9.73973039e-01],
#        [1.40492932e-02, 4.56972065e-01],
#        [9.07861288e-01, 6.29345187e-01],
#        [9.23802068e-01, 5.24243149e-01],
#        [3.15583485e-01, 4.41086635e-03],
#        [4.26834791e-02, 7.33758165e-01],
#        [9.11305914e-01, 7.11808792e-01],
#        [1.32904598e-01, 4.78406242e-01],
#        [2.73889664e-01, 4.44019323e-01],
#        [2.03561985e-01, 8.80523547e-01],
#        [6.05200238e-01, 5.79102240e-01],
#        [7.05357724e-01, 8.03596484e-01],
#        [7.34112350e-01, 1.93493711e-01],
#        [8.89440366e-01, 6.92333846e-01],
#        [7.17992710e-01, 1.22746956e-02],
#        [1.26168296e-01, 9.45632217e-01],
#        [5.56591538e-01, 6.52341254e-01],
#        [3.48546777e-01, 9.98116057e-01],
#        [7.81338580e-01, 7.23682587e-01],
#        [5.38108002e-01, 5.10685120e-01],
#        [3.71675235e-01, 2.02166256e-01],
#        [1.37644658e-01, 5.94461818e-01],
#        [2.38649089e-02, 7.55767024e-01],
#        [3.78662817e-01, 2.59813625e-01],
#        [7.59269541e-01, 4.30959977e-01],
#        [9.38887789e-01, 4.40534225e-01],
#        [4.20342189e-01, 8.87149604e-01],
#        [2.18029362e-01, 5.17855516e-01],
#        [2.70773343e-01, 9.17923495e-01],
#        [2.66622780e-01, 5.51465440e-01],
#        [2.06622088e-02, 7.25338993e-01],
#        [6.67500672e-01, 7.86016529e-01],
#        [8.74112361e-01, 1.08754767e-01],
#        [7.91830369e-01, 4.26735112e-01],
#        [5.16198079e-01, 1.15469849e-01],
#        [2.63151555e-01, 3.09565958e-01],
#        [4.43713414e-01, 3.33091769e-01],
#        [4.58583245e-01, 1.48751093e-01],
#        [9.90675782e-01, 7.54640860e-01],
#        [9.87546752e-01, 1.03489574e-01],
#        [7.78560536e-01, 1.05739512e-01],
#        [2.88986144e-01, 7.31552221e-01],
#        [5.44111998e-01, 8.65636077e-01],
#        [7.59984698e-01, 8.90461994e-02],
#        [6.28030266e-01, 5.22139242e-01],
#        [9.38043286e-01, 4.32270569e-01],
#        [1.55353325e-01, 8.05074389e-01],
#        [1.59744838e-01, 1.65760532e-01],
#        [3.23096576e-01, 5.15889062e-01],
#        [8.63673820e-01, 4.18886704e-01],
#        [4.62366397e-01, 4.95609273e-01],
#        [2.47315203e-01, 9.84779689e-02],
#        [7.93070626e-01, 5.38986931e-01],
#        [4.17045112e-01, 6.09808855e-01],
#        [7.73746615e-01, 1.03777104e-01],
#        [5.12453551e-01, 7.00803346e-01],
#        [6.87357510e-01, 9.58234512e-01],
#        [1.75900979e-02, 8.35334974e-01],
#        [2.25421884e-01, 7.77902277e-01],
#        [7.33205857e-01, 6.79637103e-01],
#        [5.03752221e-02, 8.12326121e-01],
#        [1.37306874e-01, 6.59099473e-01],
#        [7.46180645e-01, 1.23759206e-01],
#        [6.65062124e-01, 6.46255323e-01],
#        [8.77001103e-01, 6.96675478e-01],
#        [8.93169746e-01, 7.97978885e-01],
#        [5.24954070e-01, 1.38967912e-01],
#        [7.71358150e-01, 9.82169026e-01],
#        [7.35432322e-02, 1.12586733e-01],
#        [8.17613951e-01, 4.81673728e-01],
#        [3.94812507e-02, 7.60897155e-01],
#        [5.28542010e-01, 4.71487373e-01],
#        [4.43191383e-01, 1.94404334e-01],
#        [4.35183011e-01, 3.47611819e-01],
#        [1.54667161e-01, 4.57368945e-01],
#        [2.88929507e-01, 6.74325363e-01],
#        [3.52264530e-02, 3.70226293e-01],
#        [6.25818458e-01, 7.70980488e-01],
#        [2.76996223e-01, 3.85306618e-01],
#        [5.81445321e-01, 8.79587280e-01],
#        [9.37263108e-01, 7.50716070e-01],
#        [1.33004276e-01, 3.67809166e-01],
#        [8.33114148e-01, 6.63818231e-01],
#        [1.67475045e-01, 5.18722279e-01],
#        [6.82776777e-01, 7.00017668e-01],
#        [6.51446525e-01, 3.08375671e-01],
#        [6.60578266e-01, 4.15480754e-01],
#        [2.65034004e-01, 9.81823599e-01],
#        [4.00705293e-01, 3.26518424e-01],
#        [1.67896172e-01, 5.03490039e-01],
#        [8.72977209e-01, 7.59382040e-01],
#        [7.96802282e-01, 4.57828581e-01],
#        [9.89931381e-01, 2.35543828e-02],
#        [1.66836894e-02, 7.07518112e-01],
#        [8.25752339e-01, 4.02808740e-01],
#        [2.95468460e-01, 9.04094263e-02],
#        [6.23012159e-01, 8.82601903e-01],
#        [3.65416862e-01, 7.20268363e-01],
#        [3.97687275e-01, 9.27477507e-01]])

# %%
# разметка моделью
sns.scatterplot(
    data=pd.DataFrame(np.hstack([data, np.array([model.labels_]).T]), columns=['f1', 'f2', 'label']), 
    x='f1',
    y='f2',
    hue='label', 
    palette='deep',
    s=10
)

sns.scatterplot(
    pd.DataFrame(model.cluster_centers_, columns=['f1', 'f2']), 
    color='darkred', 
    x='f1',
    y='f2',
    s=200,
    label='cluster_centers'
)
# Out:
# <Axes: xlabel='f1', ylabel='f2'>

# %%
# оценка качества модели
print("Целевая функция:")
print(model.inertia_)
# Out:
# Целевая функция:
# 21.240908140891595

# %%
# попробуем иначе разместить центры кластеров
model = KMeans(n_clusters=3, random_state=0, init=[[0.5, 0], [1, 1], [0, 1]])
model.fit(data)

print("Целевая функция модели с начальными центроидами:")
print(model.inertia_)
# Out:
# Целевая функция модели с начальными центроидами:
# 34.161268178003716

# %%
# разметка моделью
sns.scatterplot(
    data=pd.DataFrame(np.hstack([data, np.array([model.labels_]).T]), columns=['f1', 'f2', 'label']), 
    x='f1',
    y='f2',
    hue='label', 
    palette='deep',
    s=10
)
sns.scatterplot(
    pd.DataFrame(model.cluster_centers_, columns=['f1', 'f2']), 
    color='darkred', 
    x='f1',
    y='f2',
    s=20,
    label='cluster_centers'
)
# Out:
# <Axes: xlabel='f1', ylabel='f2'>

# %% [markdown]
# ### Визуализация

# %% [markdown]
# Сгенерируем произвольные данные бОльшей размерности.

# %%
varied = datasets.make_blobs(
    n_samples=500, cluster_std=[1.0, 2.5, 0.5], random_state=123, n_features=3
)
data_2 = pd.DataFrame(varied[0], columns=['f1', 'f2', 'f3'])
data_2.head()
# Out:
#          f1        f2        f3
# 0  9.090242  3.468917  0.741360
# 1 -1.306870  5.814657 -0.546549
# 2  3.840042 -3.223516 -6.204020
# 3  3.061613  0.678294 -3.473177
# 4  2.081576  6.415268 -1.593688

# %%
sns.pairplot(data_2, diag_kind='hist');

# %%
# построим кластеризацию
model = KMeans(n_clusters=3, random_state=45)
model.fit(data_2)
# Out:
# KMeans(n_clusters=3, random_state=45)

# %%
# визуализируем результаты
centroids = pd.DataFrame(model.cluster_centers_, columns=['f1', 'f2', 'f3'])
# Добавление столбца с номером кластера
data_2_w_label = data_2.copy()
data_2_w_label['label'] = model.labels_.astype(str)
centroids['label'] = ['0 centroid', '1 centroid', '2 centroid']

data_all = pd.concat([data_2_w_label, centroids], ignore_index=True)

# Построение графика
pairgrid = sns.pairplot(data_all, hue='label', diag_kind='hist')

# %%
model.cluster_centers_
# Out:
# array([[ 9.46898088,  3.74390465, -0.3463602 ],
#        [ 3.79605292, -4.17444685, -5.51171565],
#        [ 0.65224069,  4.47386611, -1.69781161]])

# %% [markdown]
# ### Метод локтя

# %%
distortion = []
K = range(1, 10)
for k in tqdm(K):
    model = KMeans(n_clusters=k, random_state=4)
    model.fit(data_2)
    distortion.append(model.inertia_)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 119.48it/s]

# %%
plt.figure(figsize=(12, 8))
plt.plot(K, distortion, c='royalblue', marker='x')
plt.xlabel('Число кластеров')
plt.ylabel('Значение целевой функции')
plt.show()

# %% [markdown]
# ## Поиск аномалий

# %% [markdown]
# ### Диаграмма размаха

# %%
data_titanic = pd.read_csv('titanic.csv')
data_titanic.head(4)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000

# %%
plt.boxplot(data_titanic['Fare'].values)
plt.ylabel('Стоимость билета на корабль')
plt.title("Выбросы в сумме продаж")
plt.show()

# %% [markdown]
# Диаграмма даёт информацию обо всех выбросах. Она хранится в записи "fliers"внутри объекта boxplot. Вызовом функции get_data() из объектов получим числа. Нужные значения отделены индексами.

# %%
boxplot = plt.boxplot(data_titanic['Fare'].values)
outliers_bp = list(boxplot["fliers"][0].get_data()[1])
print("Выбросов в стоимостях билетов: ", len(outliers_bp))
# Out:
# Выбросов в стоимостях билетов:  116

# %% [markdown]
# Рассчитаем выбросы самостоятельно

# %%
l = np.quantile(data_titanic['Fare'], 0.25)
r = np.quantile(data_titanic['Fare'], 0.75)
iqr = r - l

print(data_titanic['Fare'].shape[0] - (data_titanic['Fare'].apply(lambda f: l - 1.5 * iqr < f < r + 1.5 * iqr)).sum())
# Out:
# 116

# %%
print('Верхняя граница усов:', r + 1.5 * iqr)
print(116/data_titanic.shape[0])
# Out:
# Верхняя граница усов: 65.95625
# 0.13077790304396844

# %% [markdown]
# ### Изоляционный лес

# %% [markdown]
# Пропишем количество деревьев в параметре n_estimators. Чем их больше, тем точнее результаты:

# %%
isolation_forest = IsolationForest(n_estimators=50, random_state=14, contamination=0.05)

# %% [markdown]
# Выбор аномалий по одному признаку не даст представления обо всём датасете. Изоляционный лес найдёт выбросы по нескольким признакам.
# Например, объединим данные о стоимости билета и возрасте пассажира.

# %%
data_for_iso = data_titanic[['Fare', 'Age']]

# %% [markdown]
# Функцией fit_predict() можно сразу обучить модель и получить классификацию.

# %%
isolation_forest_predictions = (isolation_forest.fit_predict(data_for_iso) == -1)

# %%
outliers_iso_tree = data_for_iso[isolation_forest_predictions]

print("Количество аномалий: ", len(outliers_iso_tree))
# Out:
# Количество аномалий:  45

# %% [markdown]
# ### KNN

# %% [markdown]
# Функция predict обученной модели KNN вернёт список, где «1» означает аномалию, а «0» — её отсутствие.

# %%
data_for_iso_scaled = StandardScaler().fit_transform(data_for_iso)

# %%
knn_model = KNN(contamination=0.05)

knn_model.fit(data_for_iso_scaled)
knn_prediction = knn_model.predict(data_for_iso_scaled) == 1
outliers_knn = data_for_iso[knn_prediction]
print("Количество аномалий (KNN): ", len(outliers_knn))
# Out:
# Количество аномалий (KNN):  36

# %% [markdown]
# Сравним результаты

# %%
map_color = {0: 'lightblue', 1: 'darkgreen'}

# %%
fig, ax = plt.subplots(1, 2, figsize=[18, 6])

for i, res in enumerate(
    [(isolation_forest_predictions, 'Isolation Forest'), 
     (knn_prediction, 'KNN')
    ]
):
    ax[i].scatter(data_for_iso['Fare'], data_for_iso['Age'], color=(pd.Series(res[0]) * 1).map(map_color))
    ax[i].set_title(f'{res[1]} Res')
    ax[i].set_xlabel('Fare')
    ax[i].set_ylabel('Age')

fig.show()

# %% [markdown]
# ## Уменьшение размерности

# %% [markdown]
# ### Отбор признаков

# %% [markdown]
# Попрактикуемся в отборе признаков на синтетических данных

# %%
x_data_generated, y_data_generated = datasets.make_classification(n_samples=100, n_features=20, scale=1, random_state=98765)

# %%
model = LogisticRegressionCV(random_state=12)
model.fit(x_data_generated, y_data_generated)
# Out:
# LogisticRegressionCV(random_state=12)

# %%
model.scores_[1].mean()
# Out:
# 0.8340000000000001

# %% [markdown]
# Выберем признаки на основе матрицы корреляций

# %%
X = np.column_stack((x_data_generated, y_data_generated))

# %%
corr_matrix = pd.DataFrame(X).corr()
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(
    corr_matrix, 
    annot = True, 
    vmin=-1, 
    vmax=1, 
    center=0, 
    cmap= 'coolwarm', 
    linewidths=3,
    linecolor='black', 
    ax=ax
)
# Out:
# <Axes: >

# %% [markdown]
# 4-17, 9-11, 9-17, 11-20

# %%
df = pd.DataFrame(x_data_generated)
df = df.loc[:, (df.columns != 4) & (df.columns != 9)]
df.shape
# Out:
# (100, 18)

# %% [markdown]
# Удалим низковариативные признаки

# %%
var = VarianceThreshold(threshold=1)
df2 = var.fit_transform(df)
df2.shape
# Out:
# (100, 9)

# %%
model = LogisticRegressionCV(random_state=12)
model.fit(df2, y_data_generated)
model.scores_[1].mean()
# Out:
# 0.85

# %% [markdown]
# ### Метод главных компонент

# %% [markdown]
# Загрузим игрушечный датасет из sklearn про ирисы

# %%
iris = datasets.load_iris(as_frame=True)
features = iris['data']
target = iris['target']
display(features.head())
features.shape
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# (150, 4)

# %% [markdown]
# Изучим распределение ирисов разного типа по признакам, а также связи между этими признаками

# %%
sns.pairplot(iris['frame'], hue='target', corner=True)

# %% [markdown]
# Для начала отмасштабируем выборку.

# %%
features_norm = StandardScaler().fit_transform(features.values)

# %%
sum([features_norm[:, i].var() for i in range(4)])
# Out:
# 4.0

# %% [markdown]
# Подберем оптимальное количество компонент, объясняющих достаточно дисперсии в исходных данных

# %%
pca = PCA(n_components = 4)
pca.fit(features_norm)
var_exp = pca.explained_variance_ratio_
cum_var_exp = np.cumsum(var_exp)

plt.bar(range(1, 5), var_exp, alpha=0.5,
        align='center', label='individual explained variance')
plt.step(range(1, 5), cum_var_exp, where='mid',
         label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Уменьшим количество признаков до двух

# %%
pca = PCA(n_components = 2)
features_reduced = pca.fit_transform(features_norm)

# %% [markdown]
# Изучим, как они были составлены

# %%
pd.DataFrame(pca.components_, columns=features.columns)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.521066         -0.269347           0.580413          0.564857
# 1           0.377418          0.923296           0.024492          0.066942

# %%
pd.DataFrame(features_norm).corr()
# Out:
#           0         1         2         3
# 0  1.000000 -0.117570  0.871754  0.817941
# 1 -0.117570  1.000000 -0.428440 -0.366126
# 2  0.871754 -0.428440  1.000000  0.962865
# 3  0.817941 -0.366126  0.962865  1.000000

# %% [markdown]
# Убедимся, что новые векторы полностью декоррелированы

# %%
pd.DataFrame(features_reduced).corr()
# Out:
#               0             1
# 0  1.000000e+00 -1.018353e-16
# 1 -1.018353e-16  1.000000e+00

# %% [markdown]
# Насколько хорошо разделимы данные по новым компонентам?

# %%
map_color[2] = 'coral'

# %%
plt.scatter(features_reduced[:, 0], features_reduced[:, 1], color=target.map(map_color))
